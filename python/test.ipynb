# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams.update({
    "text.usetex": True,  # LaTeX-Rendering aktivieren
    "font.family": "serif",
    "font.serif": ["Computer Modern"],  # oder "Latin Modern"
    "axes.labelsize": 12,
    "font.size": 12,
    "legend.fontsize": 10,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "pgf.texsystem": "pdflatex",  # LaTeX als TeX-System
    "pgf.preamble": r"\usepackage{amsmath,amsfonts,amsthm,amssymb,amsxtra,enumerate,mathtools,mathabx}"  # Die Pakete hier einfügen
})

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.xlabel(rf'$\lambda (a)$')
plt.ylabel("y-Wert")
plt.title(rf"$\partial_t u = \mathcal{{H}}(t)  \lambda $")


plt.savefig("plot.pdf")

# %%
import matplotlib
from matplotlib import pyplot
from numpy import arange

x= arange(5)
y= x**1.5

matplotlib.rc('text', usetex = True)
matplotlib.rc('font', **{'family' : "sans-serif"})
params= {'text.latex.preamble' : r'\usepackage{amsmath}'}
pyplot.rcParams.update(params)

fig= pyplot.figure(figsize=[10,7], dpi=120, facecolor=[1, 1, 1])
pyplot.plot(x, y, linewidth=2)

pyplot.title(r"$\partial$")

pyplot.show()
