# %%
import numpy as np
import matplotlib.pyplot as plt


plt.rcParams.update({
    "text.usetex": True,
    "text.latex.preamble": r"\usepackage{newtxmath}"
})

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.xlabel(rf'$\lambda (a)$')
plt.ylabel("y-Wert")
plt.title(rf"$\int_{{\mathrm{{R}}^d}} \left\vert f(x)^2 \right\vert$")


plt.savefig("/home/Bachelor-thesis/thesis/figures/plot.pdf")
